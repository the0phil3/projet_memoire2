# %%
from unidecode import unidecode
import re
import pandas as pd
import os 
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import ast
import string

# %%
df = pd.read_csv('/Users/Theo/dev/matricule_htr/output/sample_table.tsv', sep='\t')

# %%
df
# Out:
#            filename    date_naissance  taille (cm)  \
# 0    pinero_ocr.xml     20e Aout 1895        158.0
# 1        ED_ocr.xml    1Novembre 1898          NaN
# 2   pinero2_ocr.xml  29 novembre 1900        160.0
# 3  yvelines_ocr.xml  19 Février 1901        188.0
#
#                            nom      num_mat               signalement  \
# 0     CC2i Moyer Lours Argusle      5 08 fa          chibeins ovle 58
# 1      Marie François Edouard    O 191719M                       NaN
# 2      n e aurice Henri Maecel  R 1 11 1720                        60
# 3  C 1C51C2 car oé comm momion      2901 1°  chotains bruns   88 9 69
#
#   instruction                                         etat_civil  \
# 0         NaN  20e Aout 1895 Caurbes Gabeural Rgcrege Jabanel...
# 1         NaN  1Novembre 1898 e Roideaut u borps Mrrie lmmanu...
# 2         NaN  29 novembre 1900 u dil Decachon ronde e Paulin...
# 3              d 19 Février 1901 u dit Versailles e Seifectd...
#
# ...
