# %%
cd /Users/Theo/dev/yolov5/
# Out:
# /Users/Theo/dev/yolov5

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Af5OSHmioCt0FBVJCCQ4")
project = rf.workspace("fichesmat").project("document-segmenter")
dataset = project.version(2).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to document-segmenter-2 in yolov5pytorch:: 100%|█| 232/232 [00:00<00:00, 1933.59it/s

# %%
! python train.py --data "/Users/Theo/dev/projet_memoire2/document-segmenter-2/data.yaml" --batch-size 5 --device cpu --img 640 --weights yolov5x.pt --epochs 50
# Out:
# train: weights=yolov5x.pt, cfg=, data=/Users/Theo/dev/projet_memoire2/document-segmenter-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=5, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=cpu, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.9.13 torch-1.13.1 CPU
#
# ...
