# %%
import lxml, csv, requests, json, os, glob, collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/Users/Theo/Desktop/14-18/tirage/"
os.chdir(path)

# %%
test = pd.read_csv(path+'tirage_paris.csv', encoding='UTF-8', engine="python", header=0, index_col=0)

# %%
test
# Out:
#      Nom du soldat           Prénom(s) Date de naissance Lieu de naissance  \
# 0             Noël         René Marcel        16/02/1888             Seine
# 1         Bailleux        Gaston Emile        02/10/1888             Aisne
# 2          Coulaud         Louis Emile        13/02/1879             Seine
# 3          Tordier             Maurice        26/10/1891             Yonne
# 4         Coullier  Alexandre Baptiste        15/11/1901             Seine
# ...            ...                 ...               ...               ...
# 2995        Briand       Emile Martial        31/10/1882              Aube
# 2996   Carmantrant       Marcel Gaston        26/01/1898    Seine-et-Marne
# 2997       Gaspard        Paul Gustave        17/06/1893             Seine
# 2998      Valentin      Pierre Jacques        06/12/1887   Ille-et-Vilaine
# 2999      Gressier        Victor Louis        30/08/1873             Seine
#
#       Numéro de matricule  Nombre de scans  \
# ...

# %%
test[test['Numéro de matricule']==3397]
# Out:
#     Nom du soldat                Prénom(s) Date de naissance  \
# 135          Baré  Lucien François Achille        08/02/1890
# 976     Tillement                  Charles        30/03/1896
#
#     Lieu de naissance  Numéro de matricule  Nombre de scans  \
# 135             Seine               3397.0                3
# 976             Marne               3397.0                2
#
#                                                 Détail  \
# 135  https://archives.paris.fr//s/17/etats-signalet...
# 976  https://archives.paris.fr//s/17/etats-signalet...
#
#                                                   Lien  labat_id
# 135  https://archives.paris.fr//arkotheque/arkotheq...    695426
# 976  https://archives.paris.fr//arkotheque/arkotheq...    674338
